# %% [markdown]
# <a href="https://colab.research.google.com/github/theunixdisaster/Reinforcement_Learning_NPTEL/blob/main/Pandas_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

my_data = {
    "Company": [
        "Hynix",
        "Infineon",
        "Micron",
        "Samsung",
        "Others",
    ],
    "1999 Share(%)": [
        19,
        6,
        16,
        23,
        36,
    ],
    "2002 Share(%)": [
        13,
        13,
        19,
        32,
        23
    ]
}

df = pd.DataFrame(my_data)
display(df)
print()
df["1999 Share(%)"].max()
# Out:
#     Company  1999 Share(%)  2002 Share(%)
# 0     Hynix             19             13
# 1  Infineon              6             13
# 2    Micron             16             19
# 3   Samsung             23             32
# 4    Others             36             23
# 36

# %%
my_data = pd.read_csv('train.csv')
df = pd.DataFrame(my_data)
display(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

visit_data = {
    "Frequency": [
        7258, 6078, 4381, 4283
    ]
}

df = pd.DataFrame(visit_data, index=["msn.com", "yahoo.com", "google.com", "recipesource.com"],)
display(df)

df.plot.barh(y="Frequency")
df.plot.bar(y="Frequency")
df.plot.pie(y="Frequency", figsize=(5,5))
plt.show()
# Out:
#                   Frequency
# msn.com                7258
# yahoo.com              6078
# google.com             4381
# recipesource.com       4283
